# %%
# Importer les différentes bibliothèques de traitement des données
import pandas as pd, numpy as np

# %%
# Lire le fichier CSV prétraité
data  = pd.read_csv(r"./final_dataset.csv", sep = ";")

# %%
# Afficher le résultat
data
# Out:
#      sexe  age fumer  \
# 0   homme   37   Non
# 1   homme   37   Oui
# 2   femme   64   Non
# 3   homme   44   Oui
# 4   homme   25   Non
# ..    ...  ...   ...
# 86  femme   27   Non
# 87  femme   27   Non
# 88  femme   20   Non
# 89  femme   19   Non
# 90  femme   19   Non
#
#    alcool                                                                 \
# 0                                                 Non
# 1                                                 Non
# 2                                                 Non
# 3                                                 Non
# 4                                                 Non
# ..                                                ...
# 86                                                Non
# 87                                                Non
# 88                                                Non
# 89                                                Non
# 90                                                Non
#
#    sport activite_physique heures_repos maladie_chronique      maladie
# 0    Non               Oui            8               Oui  Asthmatique
# 1    Oui               Oui            9               Non          NaN
# 2    Non               Oui            9               Oui      Diab�te
# 3    Non               Non            8               Non          NaN
# 4    Non               Non            2               Non          NaN
# ..   ...               ...          ...               ...          ...
# 86   Oui               Oui          6,7               Oui      Diab�te
# 87   Oui               Oui          6,7               Oui  Asthmatique
# 88   Non               Oui           14               Oui      Tension
# 89   Non               Non            8               Oui      Diab�te
# 90   Non               Non            8               Oui  Asthmatique
#
# [91 rows x 9 columns]

# %%
# Creer une variable intervales d'ages qui classesnt les personnes selon la plage d'age ou elles appartiennet 
intervales_ages = pd.cut(data.age, bins=[0,18,25,45,70],labels=["<=18", "18-25", "25-45", "45-70"])

# Inserer cette variable dans notre dataframe
data.insert(1,"intervales_ages",intervales_ages)

# Afficher le résultat
data
# Out:
#      sexe intervales_ages  age fumer  \
# 0   homme           25-45   37   Non
# 1   homme           25-45   37   Oui
# 2   femme           45-70   64   Non
# 3   homme           25-45   44   Oui
# 4   homme           18-25   25   Non
# ..    ...             ...  ...   ...
# 86  femme           25-45   27   Non
# 87  femme           25-45   27   Non
# 88  femme           18-25   20   Non
# 89  femme           18-25   19   Non
# 90  femme           18-25   19   Non
#
#    alcool                                                                 \
# 0                                                 Non
# 1                                                 Non
# 2                                                 Non
# 3                                                 Non
# 4                                                 Non
# ..                                                ...
# 86                                                Non
# 87                                                Non
# 88                                                Non
# 89                                                Non
# 90                                                Non
#
#    sport activite_physique heures_repos maladie_chronique      maladie
# 0    Non               Oui            8               Oui  Asthmatique
# 1    Oui               Oui            9               Non          NaN
# 2    Non               Oui            9               Oui      Diab�te
# 3    Non               Non            8               Non          NaN
# 4    Non               Non            2               Non          NaN
# ..   ...               ...          ...               ...          ...
# 86   Oui               Oui          6,7               Oui      Diab�te
# 87   Oui               Oui          6,7               Oui  Asthmatique
# 88   Non               Oui           14               Oui      Tension
# 89   Non               Non            8               Oui      Diab�te
# 90   Non               Non            8               Oui  Asthmatique
#
# [91 rows x 10 columns]

# %%
# Créer une table pivot qui prend en entrée le dataframe, on applique la fonction d'aggrégation count sur les maladies en indexant lse données par intervales d'age et en gardant que les colonnes sexe et activité physique
table1 = pd.pivot_table(data, columns=["sexe","activite_physique"], index=["maladie", "intervales_ages"], aggfunc={"maladie":"count"})
table1
# Out:
#                                     maladie
# sexe                                  femme     homme
# activite_physique                       Non Oui   Non Oui
# maladie             intervales_ages
# Asthmatique         <=18                  0   1     1   0
#                     18-25                 2   0     0   1
#                     25-45                 0   2     0   1
#                     45-70                 0   0     0   0
# Cardiaque           <=18                  0   0     0   0
#                     18-25                 0   0     0   0
#                     25-45                 1   0     0   0
#                     45-70                 0   0     0   0
# Diab�te             <=18                  2   1     0   0
#                     18-25                 3   2     7   1
#                     25-45                 3   3     3   3
#                     45-70                 0   1     1   0
# Insuffisance r�nale <=18                  0   0     0   0
#                     18-25                 0   1     0   0
#                     25-45                 0   0     0   0
#                     45-70                 0   0     0   0
# Tension             <=18                  0   1     1   0
#                     18-25                 6   4     4   4
#                     25-45                 2   1     4   2
#                     45-70                 0   0     0   0

# %%
table1.to_csv("Data_diagramme_1_maladie_age_sexe_activite.csv")
